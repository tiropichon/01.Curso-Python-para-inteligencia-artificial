# %% [markdown]
# ###### Ejercicio 2.9: La palabra "seguía" aparece 4 veces en el texto. Queremos ver escrito en la pantalla las frases que siguen de "seguía" hasta que encuentra una coma o un punto, en 4 lineas diferentes. No puedes usar bucles (while, for). Hay que usar el operador ternario: https://book.pythontips.com/en/latest/ternary_operators.html. Un ejemplo del uso del operador ternario:

# %%
texto = "Pero lo que más me gustaba de aquel museo era que todo "
texto += "estaba siempre en el mismo sitio. No cambiaba nada. "
texto += "Podías ir cien mil veces distintas y el esquimal seguía "
texto += "pescando, y los pájaros seguían volando hacia el sur, "
texto += "y los ciervos seguían bebiendo en las charcas con esas "
texto += "patas tan finas y tan bonitas que tenían, y la india del "
texto += "pecho al aire seguía tejiendo su manta."
texto.count("seguía")
# Out:
# 4

# %%
sub = "seguía"

seguia = texto.find(sub)
texto = texto[seguia:]
punto = texto.find('.')
coma = texto.find(',')
end = punto if punto < coma else coma
frase1 = texto[:end]

texto = texto[end+1:]
seguia = texto.find(sub)
punto = texto.find('.')
coma = texto.find(',')
end = punto if punto < coma else coma
frase2 = texto[seguia:end]

texto = texto[end+1:]
seguia = texto.find(sub)
punto = texto.find('.')
coma = texto.find(',')
end = punto if punto < coma else coma
frase3 = texto[seguia:end]

texto = texto[end+1:]
seguia = texto.find(sub)
punto = texto.find('.')
coma = texto.find(',')
end = punto if punto < coma else coma
frase4 = texto[seguia:end]

print(frase1)
print(frase2)
print(frase3)
print(frase4)
# Out:
# seguía pescando
# seguían volando hacia el sur
# seguían bebiendo en las charcas con esas patas tan finas y tan bonitas que tenían
# seguía tejiendo su manta

# %%
# Raul 
texto = "Pero lo que más me gustaba de aquel museo era que todo "
texto += "estaba siempre en el mismo sitio. No cambiaba nada. "
texto += "Podías ir cien mil veces distintas y el esquimal seguía "
texto += "pescando, y los pájaros seguían volando hacia el sur,"
texto += "y los ciervos seguían bebiendo en las charcas con esas "
texto += "patas tan finas y tan bonitas que tenían, y la india del "
texto += "pecho al aire seguía tejiendo su manta."

word_to_check = "seguía"
lower_index = texto.find(word_to_check)
upper_index = texto.find(",")
condition = word_to_check in texto
str_1 = texto[lower_index:upper_index] if condition else ''
print(str_1)

texto = texto.replace(texto[0:upper_index+1], '')
lower_index = texto.find(word_to_check)
upper_index = texto.find(",")
condition = word_to_check in texto
str_2 = texto[lower_index:upper_index] if condition else ''
print(str_2)

texto = texto.replace(texto[0:upper_index+1], '')
lower_index = texto.find(word_to_check)
upper_index = texto.find(",")
condition = word_to_check in texto
str_3 = texto[lower_index:upper_index] if condition else ''
print(str_3)

texto = texto.replace(texto[0:upper_index+1], '')
lower_index = texto.find(word_to_check)
upper_index = texto.find(".")
condition = word_to_check in texto
str_4 = texto[lower_index:upper_index] if condition else ''
print(str_4)
texto = texto.replace(texto[0:upper_index+1], '')
print(texto)
# Out:
# seguía pescando
# seguían volando hacia el sur
# seguían bebiendo en las charcas con esas patas tan finas y tan bonitas que tenían
# seguía tejiendo su manta

# %%
# Pedro - segundo
import re

texto = "Pero lo que más me gustaba de aquel museo era que todo "
texto += "estaba siempre en el mismo sitio. No cambiaba nada. "
texto += "Podías ir cien mil veces distintas y el esquimal seguía "
texto += "pescando, y los pájaros seguían volando hacia el sur, "
texto += "y los ciervos seguían bebiendo en las charcas con esas "
texto += "patas tan finas y tan bonitas que tenían, y la india del "
texto += "pecho al aire seguía tejiendo su manta."
texto.count("seguía")

palabra = re.findall(r'seguía.*?[.,]', texto)
print(palabra)
# Out:
# ['seguía pescando,', 'seguían volando hacia el sur,', 'seguían bebiendo en las charcas con esas patas tan finas y tan bonitas que tenían,', 'seguía tejiendo su manta.']

# %%
# Pablo Cóceres
texto = "Pero lo que más me gustaba de aquel museo era que todo "

texto += "estaba siempre en el mismo sitio. No cambiaba nada. "

texto += "Podías ir cien mil veces distintas y el esquimal seguía "

texto += "pescando, y los pájaros seguían volando hacia el sur, "

texto += "y los ciervos seguían bebiendo en las charcas con esas "

texto += "patas tan finas y tan bonitas que tenían, y la india del "

texto += "pecho al aire seguía tejiendo su manta."

idx = texto.find("seguía")
punto = texto.find(".")
coma = texto.find(",")

if idx < punto :
    print(texto[idx:punto])
    idx = texto.find("seguía",punto,)
    punto = texto.find(".", punto+1,)
else:
    print(texto[idx:coma])
    idx = texto.find("seguía",coma,)
    coma = texto.find(",", coma+1,)

if idx < punto :
    print(texto[idx:punto])
    idx = texto.find("seguía",punto,)
    punto = texto.find(".", punto+1,)
else:
    print(texto[idx:coma])
    idx = texto.find("seguía",coma,)
    coma = texto.find(",", coma+1,)

if idx < punto :
    print(texto[idx:punto])
    idx = texto.find("seguía",punto,)
    punto = texto.find(".", punto+1,)
else:
    print(texto[idx:coma])
    idx = texto.find("seguía",coma,)
    coma = texto.find(",", coma+1,)

if idx < punto :
    print(texto[idx:punto])
    idx = texto.find("seguía",punto,)
    punto = texto.find(".", punto+1,)
else:
    print(texto[idx:coma])
    idx = texto.find("seguía",coma,)
    coma = texto.find(",", coma+1,)
# Out:
# seguía pescando
# seguían volando hacia el sur
# seguían bebiendo en las charcas con esas patas tan finas y tan bonitas que tenían
# seguía tejiendo su manta

# %%
# Luis

# Ejercicio 2.9: La palabra "seguía" aparece 4 veces en el texto.
#Queremos ver escrito en la pantalla las frases que siguen de "seguía"
#hasta que encuentra una coma o un punto, en 4 lineas diferentes

texto = "Pero lo que más me gustaba de aquel museo era que todo "
texto += "estaba siempre en el mismo sitio. No cambiaba nada. "
texto += "Podías ir cien mil veces distintas y el esquimal seguía "
texto += "pescando, y los pájaros seguían volando hacia el sur, "
texto += "y los ciervos seguían bebiendo en las charcas con esas "
texto += "patas tan finas y tan bonitas que tenían, y la india del "
texto += "pecho al aire seguía tejiendo su manta."

#Lo siento Spiros; pero seguramente sea el programa menos inteligente programado nunca... Lo he solucionado con lo que en España llamamos "LA CUENTA DE LA VIEJA"

x = ("seguía")
y = (".")
z = (",")
idx = texto.index("seguía")
idx1 = texto.find((x), (idx) + 5, )
idx2 = texto.find((x), (idx1) + 5, )
idx3 = texto.find((x), (idx2) + 5, )
dot = texto.index(".")
dot2 = texto.find((y), (dot) + 1 , )
dot3 = texto.find((y), (dot2) + 1 , )
comma = texto.index(",")
comma1 = texto.find((z), (comma) + 1 , )
comma2 = texto.find((z), (comma1) + 1 , )


if dot > idx:
    print(texto[(idx) : (dot)]) and (texto[(idx1) : (dot)]) and (texto[(idx2) : (dot)]) and (texto[(idx3) : (dot)])
elif dot2 > idx:
    print(texto[(idx) : (dot2)]) and (texto[(idx1) : (dot2)]) and (texto[(idx2) : (dot2)]) and (texto[(idx3) : (dot2)])
else :
    print(texto[(idx) : (dot3)]) and (texto[(idx1) : (dot3)]) and (texto[(idx2) : (dot3)]) and (texto[(idx3) : (dot3)])

if comma > idx:
    print(texto[(idx) : (comma)]) and (texto[(idx1) : (comma)]) and (texto[(idx2) : (comma)]) and (texto[(idx3) : (comma)])
if comma1 > idx:
    print(texto[(idx) : (comma1)]) and (texto[(idx1) : (comma1)]) and (texto[(idx2) : (comma1)]) and (texto[(idx3) : (comma1)])
if comma2 > idx :
    print(texto[(idx) : (comma2)]) and (texto[(idx1) : (comma2)]) and (texto[(idx2) : (comma2)]) and (texto[(idx3) : (comma2)])
# Out:
# seguía pescando, y los pájaros seguían volando hacia el sur, y los ciervos seguían bebiendo en las charcas con esas patas tan finas y tan bonitas que tenían, y la india del pecho al aire seguía tejiendo su manta
# seguía pescando
# seguía pescando, y los pájaros seguían volando hacia el sur
# seguía pescando, y los pájaros seguían volando hacia el sur, y los ciervos seguían bebiendo en las charcas con esas patas tan finas y tan bonitas que tenían

# %%
# Propuesta de resolución de Angel Ruben Alvarez Guerrero:

# -*- coding: utf-8 -*-
"""
    Código fuente del ejercicio propuesto en clase del día 11/03/2021:
    
	'La palabra "seguía" aparece 4 veces en el texto. 
	 Queremos ver escrito en la pantalla las frases 
	 que siguen de "seguía" hasta que encuentra una coma o un punto, 
	 en 4 lineas diferentes. No puedes usar bucles (while, for). 
	 Hay que usar el operador ternario.'
	 
    Autor: Angel Ruben Alvarez Guerrero
"""

# Función que devuelve un texto completo.
def devuelveTexto():
    texto = "Pero lo que más me gustaba de aquel museo era que todo "
    texto += "estaba siempre en el mismo sitio. No cambiaba nada. "
    texto += "Podías ir cien mil veces distintas y el esquimal seguía "
    texto += "pescando, y los pájaros seguían volando hacia el sur, "
    texto += "y los ciervos seguían bebiendo en las charcas con esas "
    texto += "patas tan finas y tan bonitas que tenían, y la india del "
    texto += "pecho al aire seguía tejiendo su manta."
    texto += "Todo seguía en su mismo lugar, viendo pasar el tiempo." # Línea añadida para comprobar funcionalidad.
    return texto

# Función que suma frases para crear un texto. De momento, no tiene uso.
def sumaFrases (texto, frases):
    texto = texto + frases
    return texto

# Función recursiva que va descomponiendo el texto y mostrando por pantalla
#    las frases que se indica en el ejercicio.
def recursividad(texto, palabra, contar, contador):
	retornOk = False
	texto2: str = ""
	if(contar >= contador):
		retornOk = True
	else:
		idx = texto.find(palabra)
		num1 = texto[idx:].find(",")
		num2 = texto[idx:].find(".")
		if(num1 < num2) and (num1 != -1):
			idx2 = num1  
		else:
			idx2 = num2 
		print("Salida: ", texto[idx:idx2 + idx])
		texto2 = texto[idx2 + idx:]
		contar += 1
		recursividad(texto2, palabra, contar, contador)
	#return None

# Función principal.
def main():
	palabra: str = "seguía"
	hay: int = devuelveTexto().count(palabra)
	recursividad(devuelveTexto(), palabra, 0, hay) 


if __name__ == "__main__":
    main()
# Out:
# Salida:  seguía pescando
# Salida:  seguían volando hacia el sur
# Salida:  seguían bebiendo en las charcas con esas patas tan finas y tan bonitas que tenían
# Salida:  seguía tejiendo su manta
# Salida:  seguía en su mismo lugar
