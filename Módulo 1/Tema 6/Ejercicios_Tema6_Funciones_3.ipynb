# %% [markdown]
# ## 1. Sustituye el bucle for
# Dado el siguiente script, lee e interpreta qué hace y sustituye cada bucle for por alguna de las funciones vistas: map, filter y reduce.
#
#
# ```
# numbers = [1,2,3,4,5,6]
#
# odd_numbers = []
# squared_odd_numbers = []
# total = 0
#
# # filter for odd numbers
# for number in numbers:
#    if number % 2 == 1:
#       odd_numbers.append(number)
#
# # square all odd numbers
# for number in odd_numbers:
#    squared_odd_numbers.append(number * number)
#
# # calculate total
# for number in squared_odd_numbers:
#    total += number
# ```
# Escribe un programa que pida al usuario que introduzca una serie de números y devuelva el valor representado por la variable "total"

# %%
# Escribe aquí tu código

# %% [markdown]
# ## 2. Interés compuesto
# Tenemos una lista en la que se han registrado las aportaciones de un cliente a su cuenta de ahorro a lo largo de varios trimestres.
# Cada trimestre, la entidad financiera revisa el dinero acumulado, al cual aplica una rentabilidad del 3%, a lo que se añade la aportación que se hace ese trimestre, con una rentabilidad del 1% como incentivo al ahorro.
#
# Utiliza la función reduce para calcular el saldo que tiene el cliente tras todas las aportaciones. Escribe el código que muestre la información de forma descriptiva.
#
#
#
# ```
# aportaciones = [10,3,45,22,50,8,12,70]
# ```

# %%
# Escribe aquí tu código
